# %%
# Clear any logs from previous runs
# !rmdir ".\logs\hparam_tuning" /S /Q  #Para windows

# %reload_ext tensorboard
# Out:
# rmdir: failed to remove '.\logs\hparam_tuning': No such file or directory
# rmdir: failed to remove '/S': No such file or directory
# rmdir: failed to remove '/Q': No such file or directory

# %%
import numpy as np
import pandas as pd
import time, os

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.utils import to_categorical
from tensorboard.plugins.hparams import api as hp

from keras.losses import CategoricalCrossentropy
from keras.models import Model

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split as split

# %%
np.random.seed(0)

tf.config.optimizer.set_jit(True)
scaler = StandardScaler()

# %% [markdown]
# ### Conjunto de datos: SDSS DR17

# %%
url = "https://raw.githubusercontent.com/igomezv/neurapprox/main/SDSS/star_classification.csv"
data = pd.read_csv(url)
cols = ['alpha','delta','u','g','r','i','z','redshift','class']
data = data[cols]
data.head()
# Out:
#         alpha      delta         u         g         r         i         z  \
# 0  135.689107  32.494632  23.87882  22.27530  20.39501  19.16573  18.79371
# 1  144.826101  31.274185  24.77759  22.83188  22.58444  21.16812  21.61427
# 2  142.188790  35.582444  25.26307  22.66389  20.60976  19.34857  18.94827
# 3  338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454  19.25010
# 4  345.282593  21.183866  19.43718  17.58028  16.49747  15.97711  15.54461
#
#    redshift   class
# 0  0.634794  GALAXY
# 1  0.779136  GALAXY
# 2  0.644195  GALAXY
# 3  0.932346  GALAXY
# 4  0.116123  GALAXY

# %%
data["class"]=[0 if i == "GALAXY" else 1 if i == "STAR" else 2 for i in data["class"]]
print(data.head())
data = data.to_numpy()
# Out:
#         alpha      delta         u         g         r         i         z  \
# 0  135.689107  32.494632  23.87882  22.27530  20.39501  19.16573  18.79371
# 1  144.826101  31.274185  24.77759  22.83188  22.58444  21.16812  21.61427
# 2  142.188790  35.582444  25.26307  22.66389  20.60976  19.34857  18.94827
# 3  338.741038  -0.402828  22.13682  23.77656  21.61162  20.50454  19.25010
# 4  345.282593  21.183866  19.43718  17.58028  16.49747  15.97711  15.54461
#
#    redshift  class
# 0  0.634794      0
# 1  0.779136      0
# 2  0.644195      0
# 3  0.932346      0
# 4  0.116123      0

# %%
# Divide data into X and Y and implement hot_ones in Y
def prepare_dataset(data):
    X, Y = np.empty((0)), np.empty((0))
    X = data[:,0:8]
    Y = data[:,8]
    Y = to_categorical(Y, num_classes=3)
    return X, Y

# %%
# Split dataset into train, validation and test sets
X,Y = prepare_dataset(data)

# Defines ratios, w.r.t. whole dataset.
ratio_train = 0.8
ratio_val = 0.1
ratio_test = 0.1

# Produces test split.
x_, X_test, y_, Y_test = split(X, Y, test_size = ratio_test, random_state=0)

# Adjusts val ratio, w.r.t. remaining dataset.
ratio_remaining = 1 - ratio_test
ratio_val_adjusted = ratio_val / ratio_remaining

# Produces train and val splits.
X_train, X_val, Y_train, Y_val = split(x_, y_, test_size=ratio_val_adjusted, random_state=0)

# Normalize and scale the input sets.
scaler.fit(X)
X_train = scaler.transform(X_train)
X_test  = scaler.transform(X_test)
X_val   = scaler.transform(X_val)

lenx, input_shape = np.shape(X)

# %%
# X, Y = prepare_dataset(data)
# X_train, X_test, Y_train, Y_test = split(X, Y, test_size = 0.3, random_state = 0)
# X_train = scaler.fit_transform(X_train)
# X_test  = scaler.transform(X_test)

# lenx, input_shape = np.shape(X)

# %% [markdown]
# ### Hiperparámetros del modelo

# %%
HP_LAYERS =    hp.HParam('layers', hp.Discrete([5,10,20,30,40]))
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([5,10,20,30,40]))
HP_LEARNING  = hp.HParam('learning_rate', hp.Discrete([4,8,16,32]))
# HP_BATCHSIZE = hp.HParam('batch_size', hp.Discrete([16, 32]))

callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_categorical_accuracy', mode='max',
                                   min_delta=0,
                                   patience=6,
                                   restore_best_weights=True)]
batch_size = 128
epochs = 15

# %%
# METRIC_ACCURACY = 'accuracy'
with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
# with tf.summary.FileWriter('logs/hparam_tuning', sess.graph):
#     init = tf.initialize_all_variables()
#     sess.run(init)
    hp.hparams_config(
        hparams=[HP_LAYERS, HP_NUM_UNITS, HP_LEARNING],
        metrics=[hp.Metric('loss', display_name="Accuracy")])

# %%
def train_test_model(hparams):    
    
    # Train LSTM model and predict on validation set
    model = keras.Sequential()
    model.add(Input(shape=(int(X_train.shape[1]),)))
    model.add(Dense(hparams[HP_NUM_UNITS], input_shape=(int(X_train.shape[1]),)))
    
    for i in range(hparams[HP_LAYERS]):        
        model.add(Dense(hparams[HP_NUM_UNITS], activation='relu'))
    model.add(Dense(3, activation=tf.nn.softmax))
     
    optimizer = keras.optimizers.Adam(learning_rate=hparams[HP_LEARNING]*10**(-4), beta_1=0.9, beta_2=0.999, epsilon=1e-3)
    model.compile(
            optimizer=optimizer,
            loss=CategoricalCrossentropy(),
            metrics=["categorical_accuracy"])
    
    # Run with 1 epoch to speed things up for demo purposes

    model.fit(X_train, Y_train, epochs=epochs, validation_data=(X_test, Y_test),
              callbacks=callbacks, batch_size=batch_size, shuffle=True, verbose=0)

    _, loss = model.evaluate(X_test, Y_test)
    
    return loss

# %%
def run(run_dir, hparams):
    with tf.summary.create_file_writer(run_dir).as_default():
        hp.hparams(hparams)  # record the values used in this trial
        loss = train_test_model(hparams)
        tf.summary.scalar("loss", loss, step=1)
        return loss

# %%
session_num = 0
datos = []

for deep_layers in HP_LAYERS.domain.values:
    for num_units in HP_NUM_UNITS.domain.values:
        for learning_rate in HP_LEARNING.domain.values:
#             for batch_size in HP_BATCHSIZE.domain.values:
            t = time.time()
            hparams = {

                HP_LAYERS: deep_layers,
                HP_NUM_UNITS: num_units,
                HP_LEARNING: learning_rate,
#                     HP_BATCHSIZE: batch_size
            }
            run_name = "run-%d" % session_num
            print('\n--- Starting trial: %s' % run_name)
            print({h.name: hparams[h] for h in hparams})
            score = run('logs/hparam_tuning/' + run_name, hparams)
            t = time.time()-t
            session_num += 1
            print("Accuracy:", score, "Tiempo transcurrido:", t)
            
            datos.append([deep_layers, num_units, learning_rate, score, t])

print(session_num)
# Out:
# --- Starting trial: run-0
# {'layers': 5, 'num_units': 5, 'learning_rate': 4}
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1208 - categorical_accuracy: 0.9660
# Accuracy: 0.9660000205039978 Tiempo transcurrido: 18.657504558563232
#
# --- Starting trial: run-1
# {'layers': 5, 'num_units': 5, 'learning_rate': 8}
# 313/313 [==============================] - 0s 2ms/step - loss: 0.1160 - categorical_accuracy: 0.9688
# Accuracy: 0.9688000082969666 Tiempo transcurrido: 18.659218788146973
#
# --- Starting trial: run-2
# {'layers': 5, 'num_units': 5, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1164 - categorical_accuracy: 0.9677
# Accuracy: 0.9677000045776367 Tiempo transcurrido: 21.807321786880493
#
# --- Starting trial: run-3
# {'layers': 5, 'num_units': 5, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1277 - categorical_accuracy: 0.9662
# Accuracy: 0.9661999940872192 Tiempo transcurrido: 22.467519521713257
#
# --- Starting trial: run-4
# {'layers': 5, 'num_units': 10, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1095 - categorical_accuracy: 0.9681
# Accuracy: 0.9681000113487244 Tiempo transcurrido: 21.757036924362183
#
# --- Starting trial: run-5
# {'layers': 5, 'num_units': 10, 'learning_rate': 8}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1108 - categorical_accuracy: 0.9687
# Accuracy: 0.9686999917030334 Tiempo transcurrido: 22.49481201171875
#
# --- Starting trial: run-6
# {'layers': 5, 'num_units': 10, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1040 - categorical_accuracy: 0.9686
# Accuracy: 0.9685999751091003 Tiempo transcurrido: 22.718636512756348
#
# --- Starting trial: run-7
# {'layers': 5, 'num_units': 10, 'learning_rate': 32}
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0992 - categorical_accuracy: 0.9712
# Accuracy: 0.9711999893188477 Tiempo transcurrido: 42.38098478317261
#
# --- Starting trial: run-8
# {'layers': 5, 'num_units': 20, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1109 - categorical_accuracy: 0.9671
# Accuracy: 0.9671000242233276 Tiempo transcurrido: 21.813703775405884
#
# --- Starting trial: run-9
# {'layers': 5, 'num_units': 20, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1103 - categorical_accuracy: 0.9680
# Accuracy: 0.9679999947547913 Tiempo transcurrido: 21.80170512199402
#
# --- Starting trial: run-10
# {'layers': 5, 'num_units': 20, 'learning_rate': 16}
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0975 - categorical_accuracy: 0.9702
# Accuracy: 0.9702000021934509 Tiempo transcurrido: 17.928220748901367
#
# --- Starting trial: run-11
# {'layers': 5, 'num_units': 20, 'learning_rate': 32}
# 313/313 [==============================] - 0s 2ms/step - loss: 0.1115 - categorical_accuracy: 0.9672
# Accuracy: 0.967199981212616 Tiempo transcurrido: 21.895698308944702
#
# --- Starting trial: run-12
# {'layers': 5, 'num_units': 30, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1084 - categorical_accuracy: 0.9679
# Accuracy: 0.9678999781608582 Tiempo transcurrido: 21.0830180644989
#
# --- Starting trial: run-13
# {'layers': 5, 'num_units': 30, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1052 - categorical_accuracy: 0.9683
# Accuracy: 0.9682999849319458 Tiempo transcurrido: 42.954981327056885
#
# --- Starting trial: run-14
# {'layers': 5, 'num_units': 30, 'learning_rate': 16}
# 313/313 [==============================] - 0s 2ms/step - loss: 0.1037 - categorical_accuracy: 0.9687
# Accuracy: 0.9686999917030334 Tiempo transcurrido: 19.340190172195435
#
# --- Starting trial: run-15
# {'layers': 5, 'num_units': 30, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1092 - categorical_accuracy: 0.9659
# Accuracy: 0.9659000039100647 Tiempo transcurrido: 24.231059551239014
#
# --- Starting trial: run-16
# {'layers': 5, 'num_units': 40, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1025 - categorical_accuracy: 0.9695
# Accuracy: 0.9695000052452087 Tiempo transcurrido: 42.99026942253113
#
# --- Starting trial: run-17
# {'layers': 5, 'num_units': 40, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1107 - categorical_accuracy: 0.9663
# Accuracy: 0.9663000106811523 Tiempo transcurrido: 23.636592864990234
#
# --- Starting trial: run-18
# {'layers': 5, 'num_units': 40, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1056 - categorical_accuracy: 0.9679
# Accuracy: 0.9678999781608582 Tiempo transcurrido: 42.47990894317627
#
# --- Starting trial: run-19
# {'layers': 5, 'num_units': 40, 'learning_rate': 32}
# 313/313 [==============================] - 0s 2ms/step - loss: 0.1102 - categorical_accuracy: 0.9672
# Accuracy: 0.967199981212616 Tiempo transcurrido: 42.29569101333618
#
# --- Starting trial: run-20
# {'layers': 10, 'num_units': 5, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1725 - categorical_accuracy: 0.9530
# Accuracy: 0.953000009059906 Tiempo transcurrido: 24.121060609817505
#
# --- Starting trial: run-21
# {'layers': 10, 'num_units': 5, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1297 - categorical_accuracy: 0.9596
# Accuracy: 0.9595999717712402 Tiempo transcurrido: 20.12731432914734
#
# --- Starting trial: run-22
# {'layers': 10, 'num_units': 5, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9601 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 11.889476537704468
#
# --- Starting trial: run-23
# {'layers': 10, 'num_units': 5, 'learning_rate': 32}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1270 - categorical_accuracy: 0.9601
# Accuracy: 0.960099995136261 Tiempo transcurrido: 22.703974962234497
#
# --- Starting trial: run-24
# {'layers': 10, 'num_units': 10, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1123 - categorical_accuracy: 0.9674
# Accuracy: 0.9674000144004822 Tiempo transcurrido: 42.559484004974365
#
# --- Starting trial: run-25
# {'layers': 10, 'num_units': 10, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1166 - categorical_accuracy: 0.9665
# Accuracy: 0.9664999842643738 Tiempo transcurrido: 26.29951024055481
#
# --- Starting trial: run-26
# {'layers': 10, 'num_units': 10, 'learning_rate': 16}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1141 - categorical_accuracy: 0.9666
# Accuracy: 0.9666000008583069 Tiempo transcurrido: 43.31579542160034
#
# --- Starting trial: run-27
# {'layers': 10, 'num_units': 10, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1087 - categorical_accuracy: 0.9683
# Accuracy: 0.9682999849319458 Tiempo transcurrido: 22.22768497467041
#
# --- Starting trial: run-28
# {'layers': 10, 'num_units': 20, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1163 - categorical_accuracy: 0.9652
# Accuracy: 0.9652000069618225 Tiempo transcurrido: 23.921361207962036
#
# --- Starting trial: run-29
# {'layers': 10, 'num_units': 20, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1002 - categorical_accuracy: 0.9700
# Accuracy: 0.9700000286102295 Tiempo transcurrido: 42.479411602020264
#
# --- Starting trial: run-30
# {'layers': 10, 'num_units': 20, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1015 - categorical_accuracy: 0.9699
# Accuracy: 0.9699000120162964 Tiempo transcurrido: 23.147316932678223
#
# --- Starting trial: run-31
# {'layers': 10, 'num_units': 20, 'learning_rate': 32}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1009 - categorical_accuracy: 0.9692
# Accuracy: 0.9692000150680542 Tiempo transcurrido: 42.92340421676636
#
# --- Starting trial: run-32
# {'layers': 10, 'num_units': 30, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1120 - categorical_accuracy: 0.9674
# Accuracy: 0.9674000144004822 Tiempo transcurrido: 42.51389813423157
#
# --- Starting trial: run-33
# {'layers': 10, 'num_units': 30, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1060 - categorical_accuracy: 0.9688
# Accuracy: 0.9688000082969666 Tiempo transcurrido: 22.08582043647766
#
# --- Starting trial: run-34
# {'layers': 10, 'num_units': 30, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1356 - categorical_accuracy: 0.9584
# Accuracy: 0.9584000110626221 Tiempo transcurrido: 42.715070962905884
#
# --- Starting trial: run-35
# {'layers': 10, 'num_units': 30, 'learning_rate': 32}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1084 - categorical_accuracy: 0.9686
# Accuracy: 0.9685999751091003 Tiempo transcurrido: 43.637354612350464
#
# --- Starting trial: run-36
# {'layers': 10, 'num_units': 40, 'learning_rate': 4}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1132 - categorical_accuracy: 0.9649
# Accuracy: 0.964900016784668 Tiempo transcurrido: 43.395997047424316
#
# --- Starting trial: run-37
# {'layers': 10, 'num_units': 40, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1134 - categorical_accuracy: 0.9635
# Accuracy: 0.9635000228881836 Tiempo transcurrido: 31.653900384902954
#
# --- Starting trial: run-38
# {'layers': 10, 'num_units': 40, 'learning_rate': 16}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1039 - categorical_accuracy: 0.9699
# Accuracy: 0.9699000120162964 Tiempo transcurrido: 31.984885931015015
#
# --- Starting trial: run-39
# {'layers': 10, 'num_units': 40, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1048 - categorical_accuracy: 0.9703
# Accuracy: 0.970300018787384 Tiempo transcurrido: 42.80034351348877
#
# --- Starting trial: run-40
# {'layers': 20, 'num_units': 5, 'learning_rate': 4}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1642 - categorical_accuracy: 0.9599
# Accuracy: 0.9599000215530396 Tiempo transcurrido: 43.579754114151
#
# --- Starting trial: run-41
# {'layers': 20, 'num_units': 5, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1478 - categorical_accuracy: 0.9567
# Accuracy: 0.9567000269889832 Tiempo transcurrido: 44.3886501789093
#
# --- Starting trial: run-42
# {'layers': 20, 'num_units': 5, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9603 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 14.870670318603516
#
# --- Starting trial: run-43
# {'layers': 20, 'num_units': 5, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9598 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 22.598930597305298
#
# --- Starting trial: run-44
# {'layers': 20, 'num_units': 10, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1851 - categorical_accuracy: 0.9463
# Accuracy: 0.9463000297546387 Tiempo transcurrido: 43.05426645278931
#
# --- Starting trial: run-45
# {'layers': 20, 'num_units': 10, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1133 - categorical_accuracy: 0.9672
# Accuracy: 0.967199981212616 Tiempo transcurrido: 36.99502730369568
#
# --- Starting trial: run-46
# {'layers': 20, 'num_units': 10, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1088 - categorical_accuracy: 0.9662
# Accuracy: 0.9661999940872192 Tiempo transcurrido: 43.566948890686035
#
# --- Starting trial: run-47
# {'layers': 20, 'num_units': 10, 'learning_rate': 32}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1118 - categorical_accuracy: 0.9688
# Accuracy: 0.9688000082969666 Tiempo transcurrido: 37.04910850524902
#
# --- Starting trial: run-48
# {'layers': 20, 'num_units': 20, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1076 - categorical_accuracy: 0.9666
# Accuracy: 0.9666000008583069 Tiempo transcurrido: 35.32649612426758
#
# --- Starting trial: run-49
# {'layers': 20, 'num_units': 20, 'learning_rate': 8}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1152 - categorical_accuracy: 0.9668
# Accuracy: 0.9667999744415283 Tiempo transcurrido: 33.682504415512085
#
# --- Starting trial: run-50
# {'layers': 20, 'num_units': 20, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1056 - categorical_accuracy: 0.9684
# Accuracy: 0.9684000015258789 Tiempo transcurrido: 43.23609948158264
#
# --- Starting trial: run-51
# {'layers': 20, 'num_units': 20, 'learning_rate': 32}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1069 - categorical_accuracy: 0.9673
# Accuracy: 0.9672999978065491 Tiempo transcurrido: 44.21517276763916
#
# --- Starting trial: run-52
# {'layers': 20, 'num_units': 30, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1148 - categorical_accuracy: 0.9641
# Accuracy: 0.9641000032424927 Tiempo transcurrido: 84.98622918128967
#
# --- Starting trial: run-53
# {'layers': 20, 'num_units': 30, 'learning_rate': 8}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1215 - categorical_accuracy: 0.9652
# Accuracy: 0.9652000069618225 Tiempo transcurrido: 84.72511148452759
#
# --- Starting trial: run-54
# {'layers': 20, 'num_units': 30, 'learning_rate': 16}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1014 - categorical_accuracy: 0.9714
# Accuracy: 0.9714000225067139 Tiempo transcurrido: 84.12847352027893
#
# --- Starting trial: run-55
# {'layers': 20, 'num_units': 30, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1248 - categorical_accuracy: 0.9625
# Accuracy: 0.9624999761581421 Tiempo transcurrido: 47.558549642562866
#
# --- Starting trial: run-56
# {'layers': 20, 'num_units': 40, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1004 - categorical_accuracy: 0.9696
# Accuracy: 0.9696000218391418 Tiempo transcurrido: 84.21490526199341
#
# --- Starting trial: run-57
# {'layers': 20, 'num_units': 40, 'learning_rate': 8}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1099 - categorical_accuracy: 0.9661
# Accuracy: 0.9660999774932861 Tiempo transcurrido: 84.6259036064148
#
# --- Starting trial: run-58
# {'layers': 20, 'num_units': 40, 'learning_rate': 16}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1049 - categorical_accuracy: 0.9677
# Accuracy: 0.9677000045776367 Tiempo transcurrido: 84.84235978126526
#
# --- Starting trial: run-59
# {'layers': 20, 'num_units': 40, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1116 - categorical_accuracy: 0.9698
# Accuracy: 0.9697999954223633 Tiempo transcurrido: 47.60920763015747
#
# --- Starting trial: run-60
# {'layers': 30, 'num_units': 5, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9601 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 20.046937942504883
#
# --- Starting trial: run-61
# {'layers': 30, 'num_units': 5, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9599 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 23.487287998199463
#
# --- Starting trial: run-62
# {'layers': 30, 'num_units': 5, 'learning_rate': 16}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9598 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 23.898133516311646
#
# --- Starting trial: run-63
# {'layers': 30, 'num_units': 5, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9599 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 18.075129985809326
#
# --- Starting trial: run-64
# {'layers': 30, 'num_units': 10, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1739 - categorical_accuracy: 0.9504
# Accuracy: 0.9503999948501587 Tiempo transcurrido: 47.17200016975403
#
# --- Starting trial: run-65
# {'layers': 30, 'num_units': 10, 'learning_rate': 8}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1498 - categorical_accuracy: 0.9559
# Accuracy: 0.9559000134468079 Tiempo transcurrido: 84.96020436286926
#
# --- Starting trial: run-66
# {'layers': 30, 'num_units': 10, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9600 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 44.555464029312134
#
# --- Starting trial: run-67
# {'layers': 30, 'num_units': 10, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1505 - categorical_accuracy: 0.9543
# Accuracy: 0.9542999863624573 Tiempo transcurrido: 86.05873346328735
#
# --- Starting trial: run-68
# {'layers': 30, 'num_units': 20, 'learning_rate': 4}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1711 - categorical_accuracy: 0.9552
# Accuracy: 0.9552000164985657 Tiempo transcurrido: 44.49519395828247
#
# --- Starting trial: run-69
# {'layers': 30, 'num_units': 20, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1113 - categorical_accuracy: 0.9673
# Accuracy: 0.9672999978065491 Tiempo transcurrido: 44.22848558425903
#
# --- Starting trial: run-70
# {'layers': 30, 'num_units': 20, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1134 - categorical_accuracy: 0.9672
# Accuracy: 0.967199981212616 Tiempo transcurrido: 38.74246025085449
#
# --- Starting trial: run-71
# {'layers': 30, 'num_units': 20, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1037 - categorical_accuracy: 0.9696
# Accuracy: 0.9696000218391418 Tiempo transcurrido: 44.21081805229187
#
# --- Starting trial: run-72
# {'layers': 30, 'num_units': 30, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1212 - categorical_accuracy: 0.9614
# Accuracy: 0.9613999724388123 Tiempo transcurrido: 60.76762557029724
#
# --- Starting trial: run-73
# {'layers': 30, 'num_units': 30, 'learning_rate': 8}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1139 - categorical_accuracy: 0.9678
# Accuracy: 0.9678000211715698 Tiempo transcurrido: 60.71380949020386
#
# --- Starting trial: run-74
# {'layers': 30, 'num_units': 30, 'learning_rate': 16}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1144 - categorical_accuracy: 0.9667
# Accuracy: 0.96670001745224 Tiempo transcurrido: 85.6409330368042
#
# --- Starting trial: run-75
# {'layers': 30, 'num_units': 30, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1508 - categorical_accuracy: 0.9563
# Accuracy: 0.9563000202178955 Tiempo transcurrido: 85.22783708572388
#
# --- Starting trial: run-76
# {'layers': 30, 'num_units': 40, 'learning_rate': 4}
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1210 - categorical_accuracy: 0.9627
# Accuracy: 0.9627000093460083 Tiempo transcurrido: 67.48672914505005
#
# --- Starting trial: run-77
# {'layers': 30, 'num_units': 40, 'learning_rate': 8}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1702 - categorical_accuracy: 0.9518
# Accuracy: 0.9517999887466431 Tiempo transcurrido: 43.93210411071777
#
# --- Starting trial: run-78
# {'layers': 30, 'num_units': 40, 'learning_rate': 16}
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1070 - categorical_accuracy: 0.9678
# Accuracy: 0.9678000211715698 Tiempo transcurrido: 85.9332160949707
#
# --- Starting trial: run-79
# {'layers': 30, 'num_units': 40, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1974 - categorical_accuracy: 0.9494
# Accuracy: 0.949400007724762 Tiempo transcurrido: 46.7685341835022
#
# --- Starting trial: run-80
# {'layers': 40, 'num_units': 5, 'learning_rate': 4}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9616 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 45.29188418388367
#
# --- Starting trial: run-81
# {'layers': 40, 'num_units': 5, 'learning_rate': 8}
# 313/313 [==============================] - 1s 4ms/step - loss: 0.9729 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 24.68924379348755
#
# --- Starting trial: run-82
# {'layers': 40, 'num_units': 5, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9600 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 25.839189529418945
#
# --- Starting trial: run-83
# {'layers': 40, 'num_units': 5, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9600 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 25.072010278701782
#
# --- Starting trial: run-84
# {'layers': 40, 'num_units': 10, 'learning_rate': 4}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9860 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 45.70078110694885
#
# --- Starting trial: run-85
# {'layers': 40, 'num_units': 10, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4479 - categorical_accuracy: 0.8640
# Accuracy: 0.8640000224113464 Tiempo transcurrido: 59.52625060081482
#
# --- Starting trial: run-86
# {'layers': 40, 'num_units': 10, 'learning_rate': 16}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1124 - categorical_accuracy: 0.9686
# Accuracy: 0.9685999751091003 Tiempo transcurrido: 57.59407830238342
#
# --- Starting trial: run-87
# {'layers': 40, 'num_units': 10, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9609 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 30.725923776626587
#
# --- Starting trial: run-88
# {'layers': 40, 'num_units': 20, 'learning_rate': 4}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9598 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 28.98965334892273
#
# --- Starting trial: run-89
# {'layers': 40, 'num_units': 20, 'learning_rate': 8}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1384 - categorical_accuracy: 0.9595
# Accuracy: 0.9595000147819519 Tiempo transcurrido: 52.978976011276245
#
# --- Starting trial: run-90
# {'layers': 40, 'num_units': 20, 'learning_rate': 16}
# 313/313 [==============================] - 1s 4ms/step - loss: 0.9601 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 45.482120990753174
#
# --- Starting trial: run-91
# {'layers': 40, 'num_units': 20, 'learning_rate': 32}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9607 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 26.194998025894165
#
# --- Starting trial: run-92
# {'layers': 40, 'num_units': 30, 'learning_rate': 4}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1402 - categorical_accuracy: 0.9566
# Accuracy: 0.95660001039505 Tiempo transcurrido: 79.53032326698303
#
# --- Starting trial: run-93
# {'layers': 40, 'num_units': 30, 'learning_rate': 8}
# 313/313 [==============================] - 1s 4ms/step - loss: 0.9606 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 39.045552492141724
#
# --- Starting trial: run-94
# {'layers': 40, 'num_units': 30, 'learning_rate': 16}
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1534 - categorical_accuracy: 0.9597
# Accuracy: 0.9596999883651733 Tiempo transcurrido: 86.28091669082642
#
# --- Starting trial: run-95
# {'layers': 40, 'num_units': 30, 'learning_rate': 32}
# 313/313 [==============================] - 1s 4ms/step - loss: 0.9600 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 45.183496952056885
#
# --- Starting trial: run-96
# {'layers': 40, 'num_units': 40, 'learning_rate': 4}
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1660 - categorical_accuracy: 0.9592
# Accuracy: 0.9592000246047974 Tiempo transcurrido: 86.55680656433105
#
# --- Starting trial: run-97
# {'layers': 40, 'num_units': 40, 'learning_rate': 8}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1601 - categorical_accuracy: 0.9573
# Accuracy: 0.9573000073432922 Tiempo transcurrido: 84.84612727165222
#
# --- Starting trial: run-98
# {'layers': 40, 'num_units': 40, 'learning_rate': 16}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1217 - categorical_accuracy: 0.9649
# Accuracy: 0.964900016784668 Tiempo transcurrido: 82.37697768211365
#
# --- Starting trial: run-99
# {'layers': 40, 'num_units': 40, 'learning_rate': 32}
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9598 - categorical_accuracy: 0.5907
# Accuracy: 0.5906999707221985 Tiempo transcurrido: 44.47900342941284
# 100

# %% [markdown]
# ### Guardar datos

# %%
filename = "historial_sdss_tunning.txt"
df = pd.DataFrame(datos, columns = ["Deep size", "Num units", "Learning rate", "Accuracy", "Tiempo de ejecución"])

df.sort_values(by=["Accuracy", "Tiempo de ejecución"], ascending=[0,0], ignore_index=True, inplace=True)

df.to_csv(filename, header=True, index=False, sep='\t', mode='w') # a=append, w=overwrite

# %%
df
# Out:
#     Deep size  Num units  Learning rate  Accuracy  Tiempo de ejecución
# 0          10         20             16  0.971733            95.412978
# 1           5         30             32  0.970600            86.703002
# 2           5         40              8  0.970467            93.795267
# 3          10          5             16  0.969633            71.592510
# 4          20         40              8  0.969600           152.674356
# ..        ...        ...            ...       ...                  ...
# 95         30          5              8  0.593633            66.433003
# 96         30          5             16  0.593633            64.768998
# 97         30          5             32  0.593633            63.366240
# 98         20          5             16  0.593633            56.559066
# 99         20          5              4  0.593633            55.581091
#
# [100 rows x 5 columns]

# %%
np.sum(df[["Tiempo de ejecución"]])/60/60
# Out:
# Tiempo de ejecución    3.134891
# dtype: float64

# %%
# rm -rf /tmp/tb_logs/

# %%
# %!kill 13652
# Out:
# UsageError: Line magic function `%!kill` not found.

# %%
# %reload_ext tensorboard

# %%
# %tensorboard --logdir logs/hparam_tuning
